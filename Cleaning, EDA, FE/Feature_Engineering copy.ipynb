# %% [markdown]
# # **<span style="color:Yellow;">Scaling, Imputing and Heatmaps with Supervised Learning</span>**
#
# ## **Purpose of Notebook**

# %% [markdown]
# - Load datasets
# - Sample to balance size
# - Encode categoricals
# - Scale numericals
# - Supervised imputation
# - Correlation heatmap
# - Feature selection (top 10)
#
# ---

# %% [markdown]
# ## **<span style="color:aquamarine;">Load Preprocessed and Cleaned Datasets</span>**

# %% [markdown]
# **Load Necessary Libraries**

# %%
# Basic Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, mean_squared_error
)
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy import stats
from tabulate import tabulate
from prettytable import PrettyTable
import warnings
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import pandas as pd
warnings.filterwarnings("ignore")

# %% [markdown]
# **Load Datasets**

# %%
# Display all columns of a pandas DataFrame when printed
pd.set_option('display.max_columns', None)

# US Dataset
US_data = pd.read_csv('/Users/mahnooriqbal/COMP702 Project/ML-AI-Risk-Analysis-AV-Data-/Datasets/US-cleaned_data.csv')
# UK Dataset
UK_data = pd.read_csv('/Users/mahnooriqbal/COMP702 Project/ML-AI-Risk-Analysis-AV-Data-/Datasets/UK-cleaned_data.csv')
UK_data = UK_data.drop(['latitude', 'longitude'], axis=1)

print("US Dataset Shape:", US_data.shape)
print("UK Dataset Shape:", UK_data.shape)
# Out:
# US Dataset Shape: (4372, 21)
# UK Dataset Shape: (229782, 21)

# %% [markdown]
# **Split the columns**
# - Vital to encode the catergorical and datetime columns seperately
# - Useful when trying different imputing methods
# - Allows removal on id when needed

# %%
# Identify numerical and categorical columns
numerical_columns = ['Posted Speed Limit (MPH)']
categorical_columns = [
    'Make', 'Model', 'Model Year', 'ADS Equipped?',
    'Automation System Engaged?', 'City', 'State', 'Roadway Type', 'Roadway Surface',
    'Lighting', 'Crash With', 'Highest Injury Severity Alleged',
    'SV Pre-Crash Movement', 'SV Contact Area', 'Weather', 'Country'
]
datetime_columns = ['Incident Date', 'Incident Time (24:00)']
indexing_columns = ['Report ID', 'Report Version']

# %% [markdown]
# ## **<span style="color:aquamarine;">Encode and Scale Values</span>**

# %% [markdown]
# ### **<span style="color:Hotpink;">Encoding Function</span>**
# - vital for ml models such as regression, KNN, KMeans and heatmaps as catergorical values can be used not just numerical

# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

def encode_df(df, categorical_columns, datetime_columns):

    df_encoded = df.copy()
    df_encoded = df_encoded.drop(columns=indexing_columns)

    # --- Convert datetime columns to numeric ---
    if 'Incident Date' in datetime_columns:
        df_encoded['Incident Date'] = pd.to_datetime(df_encoded['Incident Date'], errors='coerce')
        df_encoded['Incident Date'] = df_encoded['Incident Date'].astype('int64') // 10**9  # Unix timestamp

    if 'Incident Time (24:00)' in datetime_columns:
        time_parsed = pd.to_datetime(df_encoded['Incident Time (24:00)'], format='%H:%M:%S', errors='coerce')
        df_encoded['Incident Time (24:00)'] = time_parsed.dt.hour * 3600 + time_parsed.dt.minute * 60 + time_parsed.dt.second

    # --- Encode categorical columns ---
    label_encoders = {}
    for col in categorical_columns:
        le = LabelEncoder()
        df_encoded[col] = le.fit_transform(df_encoded[col].astype(str))
        label_encoders[col] = le

    return df_encoded  # ✅ Return the modified DataFrame

# %% [markdown]
# Issue with the datetime sorted as you have to convert to nuerical not categorical for date and time!

# %% [markdown]
# ### **<span style="color:Hotpink;">Scaling Function</span>**
# - vital for ml models such as regression, KNN, KMeans and heatmaps as these models work well on unbiased standardised data

# %%
def scale_df(df):
    scaled_df = df.copy()
    scaler = MinMaxScaler()
    scaled_df[df.columns] = scaler.fit_transform(df)
    return scaled_df

# %% [markdown]
# **Encoding and Scaling UK Dataset**

# %%
# Encode time and categorical columns
UK_data_encoded = encode_df(UK_data.copy(), categorical_columns, datetime_columns)
# Scale the numerical features
UK_data_scale = scale_df(UK_data_encoded)
# Check encoded data
print(tabulate(UK_data_scale.head(), headers='keys', tablefmt='pretty'))
# Out:
# +---+---------------------+---------------------+--------------------+---------------+----------------------------+-----------------------+-----------------------+--------------------+-------+--------------+-----------------+--------------------------+----------+--------------------+---------------------------------+-----------------------+---------+-----------------+---------+
# |   |        Make         |        Model        |     Model Year     | ADS Equipped? | Automation System Engaged? |     Incident Date     | Incident Time (24:00) |        City        | State | Roadway Type | Roadway Surface | Posted Speed Limit (MPH) | Lighting |     Crash With     | Highest Injury Severity Alleged | SV Pre-Crash Movement | Weather | SV Contact Area | Country |
# +---+---------------------+---------------------+--------------------+---------------+----------------------------+-----------------------+-----------------------+--------------------+-------+--------------+-----------------+--------------------------+----------+--------------------+---------------------------------+-----------------------+---------+-----------------+---------+
# | 0 | 0.8771929824561403  | 0.8448275862068965  | 0.8571428571428571 |      0.0      |            0.0             |          0.0          | 0.052119527449617786  | 0.182995760715968  |  0.0  |     0.75     |       0.0       |   0.19999999999999996    |   0.0    | 0.5454545454545454 |               0.5               |         0.875         |   0.0   |       0.5       |   1.0   |
# | 1 | 0.2982456140350877  | 0.43678160919540227 | 0.8571428571428571 |      0.0      |            0.0             |          0.0          |  0.17373175816539263  | 0.4747998115873764 |  0.0  |     0.0      |       0.0       |           0.4            |   0.0    | 0.7272727272727273 |               1.0               |        0.1875         |   0.0   |       0.5       |   1.0   |
# | 2 | 0.5263157894736842  | 0.1743295019157088  | 0.9107142857142857 |      0.0      |            0.0             | 0.0005479452054792944 |  0.6302988186240445   | 0.8377296278850683 |  0.0  |     0.75     |       0.0       |           0.0            |   1.0    | 0.5454545454545454 |               0.5               |        0.1875         |   0.0   |       0.5       |   1.0   |
# | 3 | 0.9122807017543859  | 0.14367816091954022 | 0.6785714285714285 |      0.0      |            0.0             | 0.0038356164383550606 |  0.8895066018068103   | 0.3761186999528969 |  0.0  |     0.75     |       0.0       |           0.0            |   0.0    | 0.5454545454545454 |               0.5               |        0.1875         |   0.0   |       0.5       |   1.0   |
# | 4 | 0.03508771929824561 | 0.09578544061302681 | 0.8928571428571428 |      0.0      |            0.0             | 0.004931506849313649  |  0.34746351633078526  | 0.8219500706547339 |  0.0  |     0.0      |       0.0       |   0.19999999999999996    |   1.0    | 0.5454545454545454 |               1.0               |        0.1875         |   0.0   |       0.5       |   1.0   |
# +---+---------------------+---------------------+--------------------+---------------+----------------------------+-----------------------+-----------------------+--------------------+-------+--------------+-----------------+--------------------------+----------+--------------------+---------------------------------+-----------------------+---------+-----------------+---------+

# %% [markdown]
# **Encoding and Scaling US Dataset**

# %%
# Encode time and categorical columns
US_data_encode = encode_df(US_data.copy(), categorical_columns, datetime_columns)
# Scale the numerical features
US_data_scale = scale_df(US_data_encode)
# Check encoded data
print(tabulate(US_data_scale.head(), headers='keys', tablefmt='pretty'))
# Out:
# +---+---------------------+--------------------+--------------------+---------------+----------------------------+--------------------+-----------------------+--------------------+---------------------+--------------------+-----------------+--------------------------+---------------------+--------------------+---------------------------------+-----------------------+---------+--------------------+---------+
# |   |        Make         |       Model        |     Model Year     | ADS Equipped? | Automation System Engaged? |   Incident Date    | Incident Time (24:00) |        City        |        State        |    Roadway Type    | Roadway Surface | Posted Speed Limit (MPH) |      Lighting       |     Crash With     | Highest Injury Severity Alleged | SV Pre-Crash Movement | Weather |  SV Contact Area   | Country |
# +---+---------------------+--------------------+--------------------+---------------+----------------------------+--------------------+-----------------------+--------------------+---------------------+--------------------+-----------------+--------------------------+---------------------+--------------------+---------------------------------+-----------------------+---------+--------------------+---------+
# | 0 | 0.39705882352941174 | 0.4931506849315068 | 0.6153846153846154 |      0.0      |            1.0             | 0.9997405619405093 |  0.8318276580958999   | 0.5180722891566265 | 0.7254901960784313  | 0.5714285714285714 |       0.0       |          0.3125          | 0.16666666666666666 | 0.5333333333333333 |               1.0               |        0.8125         |  0.625  | 0.7272727272727273 |   0.0   |
# | 1 | 0.39705882352941174 | 0.4931506849315068 | 0.6153846153846154 |      1.0      |            1.0             | 0.9881680521353469 |  0.8318276580958999   | 0.518781006378455  | 0.7254901960784313  | 0.5714285714285714 |       0.0       |          0.3125          | 0.16666666666666666 | 0.5333333333333333 |               1.0               |        0.8125         |  0.625  | 0.7272727272727273 |   0.0   |
# | 2 | 0.39705882352941174 | 0.502283105022831  | 0.5384615384615385 |      1.0      |            1.0             | 0.9893551778015014 |  0.6615705350938151   | 0.9078667611622963 | 0.0392156862745098  |        0.0         |       0.0       |          0.8125          | 0.6666666666666666  | 0.5333333333333333 |       0.6000000000000001        |        0.8125         |   0.0   | 0.7272727272727273 |   0.0   |
# | 3 | 0.39705882352941174 | 0.4931506849315068 | 0.6153846153846154 |      0.0      |            0.0             | 0.999504709159154  |  0.6316886726893676   | 0.5556343019135365 | 0.37254901960784315 |        0.0         |       0.0       |          0.8125          | 0.6666666666666666  | 0.6666666666666666 |               1.0               |        0.8125         |   0.0   | 0.7272727272727273 |   0.0   |
# | 4 | 0.39705882352941174 | 0.502283105022831  | 0.6153846153846154 |      0.0      |            1.0             | 0.999984276481243  |  0.34746351633078526  | 0.593905031892275  | 0.9019607843137255  |        0.0         |       0.0       |          0.875           | 0.6666666666666666  | 0.5333333333333333 |       0.6000000000000001        |        0.8125         |   0.0   | 0.2727272727272727 |   0.0   |
# +---+---------------------+--------------------+--------------------+---------------+----------------------------+--------------------+-----------------------+--------------------+---------------------+--------------------+-----------------+--------------------------+---------------------+--------------------+---------------------------------+-----------------------+---------+--------------------+---------+

# %% [markdown]
# ## **<span style="color:aquamarine;">Imputing Missing Values</span>**
# Experimentally, checking the error and precision for each imputing method before choosing the most accurate method which limits skewing.
# ### Methods of Imputing tried:
# - Mean, Median, Mode
# - Random
# - Last Occured Carried Forward
# - Regression

# %% [markdown]
# **Checking how much missing data on both datasets**

# %%
import numpy as np
from prettytable import PrettyTable

def display_missing_and_unknown_separate(dataset, dataset_name):
    # Columns that have missing or unknown values
    features_with_issues = [
        col for col in dataset.columns
        if dataset[col].isnull().sum() > 0 or
           dataset[col].astype(str).str.lower().str.contains('unknown').any()
    ]
    
    table = PrettyTable()
    table.field_names = ["Feature", "Percentage Missing", "Percentage 'Unknown'"]
    
    for col in features_with_issues:
        missing_pct = np.round(dataset[col].isnull().mean() * 100, 2)
        unknown_pct = np.round(dataset[col].astype(str).str.lower().str.contains('unknown').mean() * 100, 2)
        table.add_row([col, f"{missing_pct} %", f"{unknown_pct} %"])
    
    print(f"Missing and 'Unknown' Values in {dataset_name}:")
    print(table)

# Usage:
display_missing_and_unknown_separate(UK_data, "UK Dataset")
display_missing_and_unknown_separate(US_data, "US Dataset")
# Out:
# Missing and 'Unknown' Values in UK Dataset:
# +----------+--------------------+----------------------+
# | Feature  | Percentage Missing | Percentage 'Unknown' |
# +----------+--------------------+----------------------+
# | Lighting |       0.0 %        |        1.18 %        |
# +----------+--------------------+----------------------+
# Missing and 'Unknown' Values in US Dataset:
# +---------------------------------+--------------------+----------------------+
# |             Feature             | Percentage Missing | Percentage 'Unknown' |
# +---------------------------------+--------------------+----------------------+
# |               Make              |       0.0 %        |        0.02 %        |
# |            Model Year           |       0.32 %       |        0.0 %         |
# |    Automation System Engaged?   |       0.0 %        |        5.24 %        |
# |          Incident Date          |       0.43 %       |        0.0 %         |
# |      Incident Time (24:00)      |       4.6 %        |        0.0 %         |
# |           Roadway Type          |       0.0 %        |       13.91 %        |
# |         Roadway Surface         |       0.0 %        |       19.46 %        |
# |     Posted Speed Limit (MPH)    |      11.34 %       |        0.0 %         |
# |             Lighting            |       0.0 %        |       19.62 %        |
# |            Crash With           |       0.0 %        |       21.09 %        |
# | Highest Injury Severity Alleged |       0.0 %        |       49.11 %        |
# |      SV Pre-Crash Movement      |       0.0 %        |       17.52 %        |
# +---------------------------------+--------------------+----------------------+

# %%
def replace_unknown_with_not_provided(dataset):
    for col in dataset.columns:
        if dataset[col].dtype == object:  # Only apply to string/object columns
            dataset[col] = dataset[col].astype(str).str.replace(
                r'\bunknown\b', 'Not Provided', case=False, regex=True
            )
    return dataset

# Apply to datasets before displaying missing/unknown stats
UK_data = replace_unknown_with_not_provided(UK_data)
US_data = replace_unknown_with_not_provided(US_data)

# %% [markdown]
# # Summary:
# - Not recorded = no data entered / missing
# - Recorded as unknown = data present but value is unknown
# - UNKNOWN is couldnt capture basically = Not Provided
#
# UK Dataset:
# City, State, Country have ~5.52% unknown, but 0% missing — keep “Unknown” category; don’t treat as missing.
# Model has 1.11% missing and no unknown — impute or drop rows.
# Lighting 1.18% unknown — keep “Unknown” category.
#
# US Dataset:
# Features like Roadway Surface (19.46% Unknown), Lighting (19.62%), Crash With (21.09%), Highest Injury Severity Alleged (49.11%) have high “Unknown” rates — keep “Unknown” as a separate category.
# Posted Speed Limit has 11.34% missing — consider imputation.
# Incident Time (4.6% missing) — impute or drop depending on importance.
# Features with very low missing/unknown can be safely imputed or dropped.

# %% [markdown]
# ### **<span style="color:Hotpink;">Mean/Mode Imputer</span>**
# - **How it works:** Replaces missing values with the mean (for normally distributed data), or mode (for categorical variables).
# - **Best for:** Small amounts of missing numerical data.
# - **Limitations:** Can distort distributions and underestimate variance.

# %%
# Mean for numerical, Mode for categorical & datetime
def mode_mean_imputation(data, numerical_columns=None, categorical_columns=None, datetime_columns=None):
    data = data.copy()
    numerical_columns = numerical_columns or []
    categorical_columns = categorical_columns or []
    datetime_columns = datetime_columns or []

    for col in numerical_columns:
        if col in data.columns:
            data[col].fillna(data[col].mean(), inplace=True)

    for col in categorical_columns + datetime_columns:
        if col in data.columns:
            mode_val = data[col].mode()
            if not mode_val.empty:
                data[col].fillna(mode_val[0], inplace=True)
    return data

# %% [markdown]
# ### **<span style="color:Hotpink;">Median Imputer</span>**
# - **How it works:** Replaces missing values with the median (for normally distributed data), or mode (for categorical variables).
# - **Best for:** Small amounts of missing numerical data.
# - **Limitations:** Can distort distributions and underestimate variance.

# %%
# Median for numerical, Mode for categorical & datetime
def median_mode_imputation(data, numerical_columns=None, categorical_columns=None, datetime_columns=None):
    data = data.copy()
    numerical_columns = numerical_columns or []
    categorical_columns = categorical_columns or []
    datetime_columns = datetime_columns or []

    for col in numerical_columns:
        if col in data.columns:
            data[col].fillna(data[col].median(), inplace=True)

    for col in categorical_columns + datetime_columns:
        if col in data.columns:
            mode_val = data[col].mode()
            if not mode_val.empty:
                data[col].fillna(mode_val[0], inplace=True)
    return data

# %% [markdown]
# ### **<span style="color:Hotpink;">Random Imputer</span>**
# - **How it works:** Replaces missing by random sampling from existing values
# - **Best for:** Maintaining original distribution with enough data
# - **Limitations:** Adds randomness; may create unrealistic combinations

# %%
# Random fill from existing non-missing values
def random_imputation(data, numerical_columns=None, categorical_columns=None, datetime_columns=None):
    data = data.copy()
    numerical_columns = numerical_columns or []
    categorical_columns = categorical_columns or []
    datetime_columns = datetime_columns or []

    for col in numerical_columns + categorical_columns + datetime_columns:
        if col in data.columns:
            non_null_values = data[col].dropna().values
            if data[col].isnull().sum() > 0 and len(non_null_values) > 0:
                random_samples = np.random.choice(non_null_values, size=data[col].isnull().sum(), replace=True)
                data.loc[data[col].isnull(), col] = random_samples
    return data

# %% [markdown]
# ### **<span style="color:Hotpink;">Last Occurance Carried Forward (LOCF) Imputer</span>**
# - **How it works:** Replaces missing by random sampling from existing values
# - **Best for:** Maintaining original distribution with enough data
# - **Limitations:** Adds randomness; may create unrealistic combinations

# %%
# Backward fill for all
def last_occurrence_imputation(data, numerical_columns=None, categorical_columns=None, datetime_columns=None):
    data = data.copy()
    numerical_columns = numerical_columns or []
    categorical_columns = categorical_columns or []
    datetime_columns = datetime_columns or []

    for col in numerical_columns + categorical_columns + datetime_columns:
        if col in data.columns:
            data[col].fillna(method='bfill', inplace=True)
    return data

# %% [markdown]
# ### **<span style="color:Hotpink;">Regression Imputer</span>**
# - **How it works:** Predicts missing values using regression models on other features
# - **Best for:** When strong relationships exist between features
# - **Limitations:** Assumes linearity; risk of overfitting if data is small

# %%
def regression_imputer(df, numerical_columns=None, categorical_columns=None, datetime_columns=None):
    df_copy = df.copy()
    
    if numerical_columns is None:
        numerical_columns = []
    if categorical_columns is None:
        categorical_columns = []
    if datetime_columns is None:
        datetime_columns = []
    
    # Impute numerical columns using IterativeImputer if any numerical columns exist
    if numerical_columns:
        imputer = IterativeImputer(random_state=0)
        imputed_num = imputer.fit_transform(df_copy[numerical_columns])
        imputed_num_df = pd.DataFrame(imputed_num, columns=numerical_columns, index=df_copy.index)
    else:
        imputed_num_df = pd.DataFrame(index=df_copy.index)
    
    # Impute categorical columns using mode if any exist
    if categorical_columns:
        imputed_cat_df = df_copy[categorical_columns].fillna(df_copy[categorical_columns].mode().iloc[0])
    else:
        imputed_cat_df = pd.DataFrame(index=df_copy.index)
    
    # Impute datetime columns using forward fill if any exist
    if datetime_columns:
        imputed_dt_df = df_copy[datetime_columns].fillna(method='ffill')
    else:
        imputed_dt_df = pd.DataFrame(index=df_copy.index)
    
    # Combine all imputed parts (only those with columns)
    imputed_df = pd.concat([df_copy.drop(columns=numerical_columns + categorical_columns + datetime_columns, errors='ignore'),
                            imputed_num_df, imputed_cat_df, imputed_dt_df], axis=1)
    # Optional: reorder columns to match original df
    imputed_df = imputed_df[df_copy.columns]
    
    return imputed_df

# %% [markdown]
# ### **<span style="color:Hotpink;">Regression Imputer</span>**
# - only for posted speed US 11% missing
# - treat as categorical

# %%
imputing_df = US_data.copy()
imputing_df['Posted Speed Limit (MPH)'].isnull().sum()

def random_forest_imputer_encoded_only(original_df, encoded_df, target_column):
    # Align indices
    original_df = original_df.reset_index(drop=True)
    encoded_df = encoded_df.reset_index(drop=True)

    # Ensure target is categorical and get codes
    original_df[target_column] = original_df[target_column].astype('category')
    target_codes = original_df[target_column].cat.codes.replace(-1, np.nan)  # NaNs stay NaN

    # Add target to encoded_df for modeling
    model_df = encoded_df.copy()
    model_df['target_code'] = target_codes

    # Split data
    df_not_missing = model_df[model_df['target_code'].notnull()]
    df_missing = model_df[model_df['target_code'].isnull()]

    X_train = df_not_missing.drop(columns=['target_code'])
    y_train = df_not_missing['target_code'].astype(int)
    X_pred = df_missing.drop(columns=['target_code'])

    if X_pred.empty:
        print("⚠️ No missing values to predict.")
        return encoded_df

    # Train and predict
    model = RandomForestClassifier(n_estimators=100, random_state=42)
    model.fit(X_train, y_train)
    predicted_codes = model.predict(X_pred)

    # Fill missing values in encoded_df directly
    encoded_df.loc[df_missing.index, target_column] = predicted_codes

    return encoded_df

US_data_encoded_imputed = random_forest_imputer_encoded_only(
    original_df=imputing_df,        # for target labels
    encoded_df=US_data_scale,       # numeric, model-ready data
    target_column='Posted Speed Limit (MPH)'  # column to fill (in encoded_df)
)

# Check results
print(US_data_encoded_imputed['Posted Speed Limit (MPH)'].isnull().sum())  # should be 0
# Out:
# 0

# %% [markdown]
# **Main hyperparameters in your code:**
# n_estimators=100
# Number of trees in the forest. More trees usually improve performance but increase computation time.
# random_state=42
# Seed for reproducibility.

# %%
from sklearn.metrics import confusion_matrix
import numpy as np

def evaluate_imputer_with_per_class_accuracy(original_df, encoded_df, target_column, test_size=0.2, random_state=42):
    original_df[target_column] = original_df[target_column].astype('category')
    categories = original_df[target_column].cat.categories

    # Filter non-missing rows
    non_missing_mask = original_df[target_column].notnull()
    full_data = original_df[non_missing_mask].copy()
    full_encoded = encoded_df[non_missing_mask].copy()

    # Numeric codes
    full_data['target_code'] = full_data[target_column].cat.codes

    # Randomly mask test samples
    np.random.seed(random_state)
    mask = np.random.rand(len(full_data)) < test_size
    test_indices = full_data.index[mask]

    # Train/test split
    X_train = full_encoded.drop(index=test_indices)
    y_train = full_data.loc[~mask, 'target_code']

    X_test = full_encoded.loc[test_indices]
    y_true = full_data.loc[mask, 'target_code']

    # Train model
    clf = RandomForestClassifier(n_estimators=100, random_state=random_state)
    clf.fit(X_train, y_train)

    # Predict
    y_pred = clf.predict(X_test)

    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred, labels=range(len(categories)))

    total_samples = cm.sum()
    total_correct = np.trace(cm)  # total TP across all classes

    overall_accuracy = total_correct / total_samples

    results = {}

    for i, class_label in enumerate(categories):
        TP = cm[i, i]
        FP = cm[:, i].sum() - TP
        FN = cm[i, :].sum() - TP
        TN = total_samples - TP - FP - FN

        class_accuracy = (TP + TN) / (TP + TN + FP + FN)

        results[class_label] = {
            "TP": TP,
            "FP": FP,
            "FN": FN,
            "TN": TN,
            "Accuracy": class_accuracy
        }

    return overall_accuracy, results

overall_acc, per_class_metrics = evaluate_imputer_with_per_class_accuracy(US_data, US_data_scale, 'Posted Speed Limit (MPH)')

print(f"Overall Accuracy: {overall_acc:.4f}\n")
for cls, metrics in per_class_metrics.items():
    print(f"Class {cls}: TP={metrics['TP']}, FP={metrics['FP']}, FN={metrics['FN']}, TN={metrics['TN']}, Accuracy={metrics['Accuracy']:.4f}")
# Out:
# Overall Accuracy: 0.9598
#
# Class 0.0: TP=0, FP=0, FN=0, TN=796, Accuracy=1.0000
# Class 1.0: TP=0, FP=0, FN=0, TN=796, Accuracy=1.0000
# Class 4.0: TP=0, FP=0, FN=0, TN=796, Accuracy=1.0000
# Class 5.0: TP=0, FP=0, FN=0, TN=796, Accuracy=1.0000
# Class 9.0: TP=0, FP=0, FN=0, TN=796, Accuracy=1.0000
# Class 10.0: TP=0, FP=0, FN=0, TN=796, Accuracy=1.0000
# Class 15.0: TP=20, FP=0, FN=2, TN=774, Accuracy=0.9975
# Class 20.0: TP=14, FP=0, FN=2, TN=780, Accuracy=0.9975
# Class 25.0: TP=216, FP=3, FN=0, TN=577, Accuracy=0.9962
# Class 30.0: TP=54, FP=1, FN=1, TN=740, Accuracy=0.9975
# Class 32.0: TP=0, FP=0, FN=1, TN=795, Accuracy=0.9987
# Class 35.0: TP=60, FP=2, FN=1, TN=733, Accuracy=0.9962
# Class 40.0: TP=39, FP=0, FN=2, TN=755, Accuracy=0.9975
# Class 43.0: TP=0, FP=0, FN=0, TN=796, Accuracy=1.0000
# Class 45.0: TP=63, FP=4, FN=4, TN=725, Accuracy=0.9899
# Class 50.0: TP=20, FP=1, FN=5, TN=770, Accuracy=0.9925
# Class 55.0: TP=56, FP=11, FN=1, TN=728, Accuracy=0.9849
# Class 57.0: TP=0, FP=0, FN=0, TN=796, Accuracy=1.0000
# Class 59.0: TP=0, FP=0, FN=1, TN=795, Accuracy=0.9987
# Class 60.0: TP=17, FP=1, FN=4, TN=774, Accuracy=0.9937
# Class 65.0: TP=148, FP=4, FN=0, TN=644, Accuracy=0.9950
# Class 70.0: TP=48, FP=5, FN=3, TN=740, Accuracy=0.9899
# Class 75.0: TP=9, FP=0, FN=5, TN=782, Accuracy=0.9937
# Class 80.0: TP=0, FP=0, FN=0, TN=796, Accuracy=1.0000

# %%
# Imputing the rest of the columns
def random_forest_impute_columns(original_df, encoded_df, target_columns):
    original_df = original_df.reset_index(drop=True)
    encoded_df = encoded_df.reset_index(drop=True)
    imputed_df = original_df.copy()

    for column in target_columns:
        if original_df[column].isnull().sum() == 0:
            continue

        print(f"🔧 Imputing: {column}")
        is_categorical = pd.api.types.is_categorical_dtype(original_df[column]) or original_df[column].dtype == object

        # Encode target
        if is_categorical:
            original_df[column] = original_df[column].astype('category')
            target = original_df[column].cat.codes.replace(-1, np.nan)
        else:
            target = original_df[column]

        model_df = encoded_df.copy()
        model_df['target'] = target

        df_not_missing = model_df[model_df['target'].notnull()]
        df_missing = model_df[model_df['target'].isnull()]

        if df_missing.empty:
            print(f"⚠️ Nothing to impute for {column}")
            continue

        X_train = df_not_missing.drop(columns=['target'])
        y_train = df_not_missing['target']
        X_pred = df_missing.drop(columns=['target'])

        # Choose model type
        if is_categorical:
            model = RandomForestClassifier(n_estimators=100, random_state=42)
        else:
            model = RandomForestRegressor(n_estimators=100, random_state=42)

        model.fit(X_train, y_train)
        predictions = model.predict(X_pred)

        # Decode back to original
        if is_categorical:
            categories = original_df[column].cat.categories
            predicted_values = pd.Series(predictions).round().astype(int).clip(0, len(categories)-1)
            imputed_df.loc[df_missing.index, column] = categories[predicted_values].values
        else:
            imputed_df.loc[df_missing.index, column] = predictions

    return imputed_df
columns_to_impute = [
    'Highest Injury Severity Alleged',
    'Crash With',
    'Roadway Surface',
    'Lighting',
    'SV Pre-Crash Movement',
    'Roadway Type'
]

US_data_fully_imputed = random_forest_impute_columns(
    original_df=final_US_imputed,
    encoded_df=US_data_scale,
    target_columns=columns_to_impute
)

print("✅ Remaining missing values:\n", US_data_fully_imputed[columns_to_impute].isnull().sum())
# Out:
# ✅ Remaining missing values:
#  Highest Injury Severity Alleged    0
# Crash With                         0
# Roadway Surface                    0
# Lighting                           0
# SV Pre-Crash Movement              0
# Roadway Type                       0
# dtype: int64

# %%
from sklearn.metrics import accuracy_score, r2_score, mean_squared_error
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor

def evaluate_random_forest_imputation(original_df, encoded_df, target_column, test_fraction=0.2, random_state=42):
    df = original_df.copy().reset_index(drop=True)
    encoded = encoded_df.copy().reset_index(drop=True)
    
    # Get non-null indices
    known_indices = df[df[target_column].notnull()].index.tolist()
    np.random.seed(random_state)
    test_indices = np.random.choice(known_indices, size=int(len(known_indices) * test_fraction), replace=False)
    
    # Store true values
    true_values = df.loc[test_indices, target_column].copy()

    # Mask test values
    df.loc[test_indices, target_column] = np.nan
    
    # Use existing imputer function
    imputed_df = random_forest_impute_columns(df, encoded, [target_column])

    # Get predictions
    predicted = imputed_df.loc[test_indices, target_column]

    is_categorical = pd.api.types.is_categorical_dtype(true_values) or true_values.dtype == object

    if is_categorical:
        true_values = pd.Series(true_values).astype('category')
        predicted = pd.Series(predicted).astype('category')
        # Ensure same categories
        acc = accuracy_score(true_values, predicted)
        print(f"🎯 Accuracy for '{target_column}': {acc:.4f}")
        return acc
    else:
        r2 = r2_score(true_values, predicted)
        rmse = mean_squared_error(true_values, predicted, squared=False)
        print(f"🎯 R² for '{target_column}': {r2:.4f}")
        print(f"📉 RMSE for '{target_column}': {rmse:.4f}")
        return r2, rmse

evaluate_random_forest_imputation(final_US_imputed, US_data_scale, 'Highest Injury Severity Alleged')
evaluate_random_forest_imputation(final_US_imputed, US_data_scale, 'Crash With')
# Out:
# 🔧 Imputing: Highest Injury Severity Alleged
# 🎯 Accuracy for 'Highest Injury Severity Alleged': 0.9908
# 🔧 Imputing: Crash With
# 🎯 Accuracy for 'Crash With': 0.9600
# 0.959954233409611

# %% [markdown]
# ### **<span style="color:GreenYellow;">Evaluating: Imputing Methods</span>**
# - For each column type trying every single imputing method to see which scores better

# %% [markdown]
# **Support Functions for Imputer Test**

# %%
# ---------- helpers ---------- #
def masked_rmse(imputed, original, mask):
    """RMSE only on the cells that were masked *and* successfully imputed."""
    flat_mask = (mask & imputed.notna() & original.notna()).values.flatten()
    if not flat_mask.any():
        return np.nan
    y_true = original.values.flatten()[flat_mask]
    y_pred = imputed.values.flatten()[flat_mask]
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
def unified_imputer_test(
        data,
        numerical_columns=None,
        categorical_columns=None,
        datetime_columns=None,
        bar_width=0.6,
        figsize=(8, 5),
        rmse_bar_color="#aec6cf", # default pastel blue
        title ="Imputation Error"
):
    numerical_columns = numerical_columns or []
    categorical_columns = categorical_columns or []
    datetime_columns = datetime_columns or []

    selected = numerical_columns + categorical_columns + datetime_columns
    original = data.dropna(subset=selected)[selected].copy()

    # Create a 20% mask
    rng = np.random.default_rng(0)
    mask = pd.DataFrame(rng.random(original.shape) < 0.20,
                        index=original.index, columns=original.columns)
    masked = original.mask(mask)

    # Run imputers
    median_mode = median_mode_imputation(masked.copy(),
                                         numerical_columns, categorical_columns, datetime_columns)
    mode_mean = mode_mean_imputation(masked.copy(),
                                     numerical_columns, categorical_columns, datetime_columns)
    last_occ = last_occurrence_imputation(masked.copy(),
                                         numerical_columns, categorical_columns, datetime_columns)
    random_imp = random_imputation(masked.copy(),
                                  numerical_columns, categorical_columns, datetime_columns)
    regress_imp = regression_imputer(masked.copy(), numerical_columns, datetime_columns)  # only numerical

    imputers = {
        "Median‑Mode": median_mode,
        "Mode‑Mean": mode_mean,
        "Last Occur.": last_occ,
        "Random": random_imp,
        "Regression": regress_imp
    }

    # Compute RMSE scores only
    rmse_scores = {}
    for name, df_imp in imputers.items():
        if numerical_columns:
            rmse_scores[name] = masked_rmse(
                df_imp[numerical_columns], original[numerical_columns], mask[numerical_columns])

    # Plot RMSE only
    plt.figure(figsize=figsize)
    if rmse_scores:
        rmses = list(rmse_scores.values())
        labels_rmse = list(rmse_scores.keys())
        bars = plt.bar(labels_rmse, rmses, width=bar_width, color=rmse_bar_color)
        plt.ylabel(f"RMSE {title}")
        plt.title(f"{title}")
        plt.xticks(rotation=45, ha='right')
        plt.grid(True, axis='y', linestyle='--', alpha=0.7)
        for b, v in zip(bars, rmses):
            plt.text(b.get_x() + b.get_width() / 2, b.get_height(),
                     f"{v:.3f}", ha='center', va='bottom', fontsize=8)

    plt.tight_layout()
    plt.show()

    return {"RMSE": rmse_scores}

# %% [markdown]
# **Numerical Columns**

# %%
print("UK Numerical Imputing Results")
unified_imputer_test(UK_data_scale.copy(), numerical_columns=numerical_columns, rmse_bar_color="lightgreen",title="Numerical Imputation Error")
print("US Numerical Imputing Results")
unified_imputer_test(US_data_scale.copy(), numerical_columns=numerical_columns, rmse_bar_color="Plum",title="Numerical Imputation Error")
# Out:
# UK Numerical Imputing Results
# US Numerical Imputing Results
# {'RMSE': {'Median‑Mode': 0.22842752228875318,
#   'Mode‑Mean': 0.22530125564254685,
#   'Last\xa0Occur.': 0.19494007924395984,
#   'Random': 0.3120435645496264,
#   'Regression': 0.22530125564254685}}

# %% [markdown]
# **Catergorical Columns**

# %%
print("UK Categorical Imputing Results")
unified_imputer_test(UK_data_scale.copy(), numerical_columns=categorical_columns,rmse_bar_color="lightgreen",title="Catergorical Imputation Error")
print("US Categorical Imputing Results")
unified_imputer_test(US_data_scale.copy(), numerical_columns=categorical_columns,rmse_bar_color="Plum",title="Catergorical Imputation Error")
# Out:
# UK Categorical Imputing Results
# US Categorical Imputing Results
# {'RMSE': {'Median‑Mode': 0.34633493010647026,
#   'Mode‑Mean': 0.29098523372703333,
#   'Last\xa0Occur.': 0.30253967599911463,
#   'Random': 0.41361457344623004,
#   'Regression': 0.22469816267886414}}

# %% [markdown]
# **DateTime Columns**

# %%
UK_data_scale.copy()

print("UK Datetime Imputing Results")
unified_imputer_test(UK_data_scale.copy(), numerical_columns=datetime_columns,rmse_bar_color="lightgreen",title="Date Time Imputation Error")
print("US Datetime Imputing Results")
unified_imputer_test(US_data_scale.copy(), numerical_columns=datetime_columns,rmse_bar_color="Plum",title="Date Time Imputation Error")
# Out:
# UK Datetime Imputing Results
# US Datetime Imputing Results
# {'RMSE': {'Median‑Mode': 0.20142265645861787,
#   'Mode‑Mean': 0.20049363132508458,
#   'Last\xa0Occur.': 0.28822832850162916,
#   'Random': 0.28625265026792335,
#   'Regression': 0.20049362961481218}}

# %% [markdown]
# **Final Imputation Statergy**
# - Last occured for all columns as has the least amount of error
# - Note: regression can be used on catergorical as encoded
#
# **UK Data**
# - Numerical = Mode Mean or Regression
# - Catergorical = Regression
# - Datetime = Last Occured
#
# **US Data**
# - Numerical = Last Occured
# - Catergorical = Regression
# - Datetime = Mode Mean or Mode Median or Regression

# %% [markdown]
# ### Final Imputing (removal of unknown and nulls) + imputing posted speed limits for US

# %%
# UK imputing 
import pandas as pd
# Make a copy of your data to avoid modifying the original
final_UK_imputed = UK_data.copy()
# Drop rows with any NaN values
final_UK_imputed = final_UK_imputed.dropna()
# Drop rows where any cell contains "unknown" (case-insensitive)
final_UK_imputed = final_UK_imputed[
    ~final_UK_imputed.astype(str).apply(lambda row: row.str.lower().str.contains("unknown")).any(axis=1)
]

# Show the resulting shape
print("Shape after cleaning:", final_UK_imputed.shape)
# Out:
# Shape after cleaning: (229782, 21)

# %%
import pandas as pd
from tabulate import tabulate

# Assuming these functions and variables are defined somewhere:
# - encode_df(df, categorical_columns, datetime_columns)
# - scale_df(df)
# - random_forest_imputer_encoded_only(original_df, encoded_df, target_column)
# - categorical_columns, datetime_columns
# - US_data (original dataframe)
# - final_imputing_df (likely your cleaned original dataframe before encoding)

# Step 1: Clean the US data (drop NaNs and 'unknown' except in 'Posted Speed Limit (MPH)')
final_US_imputed = US_data.copy()

cols_to_check_na = final_US_imputed.columns.difference(['Posted Speed Limit (MPH)'])
final_US_imputed = final_US_imputed.dropna(subset=cols_to_check_na)

cols_to_check_unknown = final_US_imputed.columns.difference(['Posted Speed Limit (MPH)'])
mask = final_US_imputed[cols_to_check_unknown].astype(str).apply(
    lambda row: row.str.lower().str.contains("unknown")).any(axis=1)
final_US_imputed = final_US_imputed[~mask]

print("Shape after cleaning:", final_US_imputed.shape)

# Step 2: Encode and scale the data (use the cleaned data)
US_data_encode = encode_df(final_US_imputed.copy(), categorical_columns, datetime_columns)
US_data_scale = scale_df(US_data_encode)

print(tabulate(US_data_scale.head(), headers='keys', tablefmt='pretty'))

# Step 3: Impute 'Posted Speed Limit (MPH)' on the cleaned and scaled data
final_US_Imputing = random_forest_imputer_encoded_only(
    original_df=final_US_imputed,       # cleaned original data before encoding
    encoded_df=US_data_scale,           # scaled encoded data
    target_column='Posted Speed Limit (MPH)'
)

print("Shape after imputation:", final_US_Imputing.shape)
# Out:
# Shape after cleaning: (4358, 21)
# +---+--------------------+--------------------+--------------------+---------------+----------------------------+--------------------+-----------------------+--------------------+---------------------+--------------------+-----------------+--------------------------+---------------------+--------------------+---------------------------------+-----------------------+---------+--------------------+---------+
# |   |        Make        |       Model        |     Model Year     | ADS Equipped? | Automation System Engaged? |   Incident Date    | Incident Time (24:00) |        City        |        State        |    Roadway Type    | Roadway Surface | Posted Speed Limit (MPH) |      Lighting       |     Crash With     | Highest Injury Severity Alleged | SV Pre-Crash Movement | Weather |  SV Contact Area   | Country |
# +---+--------------------+--------------------+--------------------+---------------+----------------------------+--------------------+-----------------------+--------------------+---------------------+--------------------+-----------------+--------------------------+---------------------+--------------------+---------------------------------+-----------------------+---------+--------------------+---------+
# | 0 | 0.3939393939393939 | 0.492822966507177  | 0.6666666666666666 |      0.0      |            1.0             | 0.9997405619405093 |  0.8318276580958999   | 0.5184659090909091 | 0.7254901960784313  | 0.7142857142857142 |       0.0       |          0.3125          | 0.16666666666666666 |        0.6         |               0.8               |         0.875         |  0.625  | 0.7272727272727273 |   0.0   |
# | 1 | 0.3939393939393939 | 0.492822966507177  | 0.6666666666666666 |      1.0      |            1.0             | 0.9881680521353469 |  0.8318276580958999   | 0.5191761363636364 | 0.7254901960784313  | 0.7142857142857142 |       0.0       |          0.3125          | 0.16666666666666666 |        0.6         |               0.8               |         0.875         |  0.625  | 0.7272727272727273 |   0.0   |
# | 2 | 0.3939393939393939 | 0.5023923444976076 | 0.5833333333333333 |      1.0      |            1.0             | 0.9893551778015014 |  0.6615705350938151   | 0.9083806818181819 | 0.0392156862745098  |        0.0         |       0.0       |          0.8125          | 0.6666666666666666  |        0.6         |       0.6000000000000001        |         0.875         |   0.0   | 0.7272727272727273 |   0.0   |
# | 3 | 0.3939393939393939 | 0.492822966507177  | 0.6666666666666666 |      0.0      |            0.0             | 0.999504709159154  |  0.6316886726893676   | 0.5561079545454546 | 0.37254901960784315 |        0.0         |       0.0       |          0.8125          | 0.6666666666666666  | 0.7333333333333333 |               0.8               |         0.875         |   0.0   | 0.7272727272727273 |   0.0   |
# | 4 | 0.3939393939393939 | 0.5023923444976076 | 0.6666666666666666 |      0.0      |            1.0             | 0.999984276481243  |  0.34746351633078526  | 0.5944602272727273 | 0.9019607843137255  |        0.0         |       0.0       |          0.875           | 0.6666666666666666  |        0.6         |       0.6000000000000001        |         0.875         |   0.0   | 0.2727272727272727 |   0.0   |
# +---+--------------------+--------------------+--------------------+---------------+----------------------------+--------------------+-----------------------+--------------------+---------------------+--------------------+-----------------+--------------------------+---------------------+--------------------+---------------------------------+-----------------------+---------+--------------------+---------+
# Shape after imputation: (4358, 19)

# %%
import numpy as np

# Step 1: Replace 'unknown' with NaN (excluding 'Posted Speed Limit (MPH)' if needed)
final_US_imputed = US_data.copy()

cols_to_replace_unknown = final_US_imputed.columns.difference(['Posted Speed Limit (MPH)'])
final_US_imputed[cols_to_replace_unknown] = final_US_imputed[cols_to_replace_unknown].replace(
    to_replace='(?i)^unknown$', value=np.nan, regex=True
)

print("Shape after replacing 'unknown' with NaN:", final_US_imputed.shape)

# Step 2: Encode and scale the data
US_data_encode = encode_df(final_US_imputed.copy(), categorical_columns, datetime_columns)
US_data_scale = scale_df(US_data_encode)

print(tabulate(US_data_scale.head(), headers='keys', tablefmt='pretty'))

# Step 3: Impute all missing values on the encoded & scaled data
# Note: Modify this to your imputer function if it only handles one column
final_US_Imputing = impute_all_missing_values(
    original_df=final_US_imputed,       # raw data (with NaNs)
    encoded_df=US_data_scale            # processed data
)

print("Shape after full imputation:", final_US_Imputing.shape)
# Out:
# Shape after replacing 'unknown' with NaN: (4372, 21)
# +---+---------------------+--------------------+--------------------+---------------+----------------------------+--------------------+-----------------------+--------------------+---------------------+--------------------+-----------------+--------------------------+---------------------+--------------------+---------------------------------+-----------------------+---------+--------------------+---------+
# |   |        Make         |       Model        |     Model Year     | ADS Equipped? | Automation System Engaged? |   Incident Date    | Incident Time (24:00) |        City        |        State        |    Roadway Type    | Roadway Surface | Posted Speed Limit (MPH) |      Lighting       |     Crash With     | Highest Injury Severity Alleged | SV Pre-Crash Movement | Weather |  SV Contact Area   | Country |
# +---+---------------------+--------------------+--------------------+---------------+----------------------------+--------------------+-----------------------+--------------------+---------------------+--------------------+-----------------+--------------------------+---------------------+--------------------+---------------------------------+-----------------------+---------+--------------------+---------+
# | 0 | 0.39705882352941174 | 0.4931506849315068 | 0.6153846153846154 |      0.0      |            1.0             | 0.9997405619405093 |  0.8318276580958999   | 0.5180722891566265 | 0.7254901960784313  | 0.7142857142857142 |       0.0       |          0.3125          | 0.16666666666666666 |        0.6         |               0.8               |         0.875         |  0.625  | 0.7272727272727273 |   0.0   |
# | 1 | 0.39705882352941174 | 0.4931506849315068 | 0.6153846153846154 |      1.0      |            1.0             | 0.9881680521353469 |  0.8318276580958999   | 0.518781006378455  | 0.7254901960784313  | 0.7142857142857142 |       0.0       |          0.3125          | 0.16666666666666666 |        0.6         |               0.8               |         0.875         |  0.625  | 0.7272727272727273 |   0.0   |
# | 2 | 0.39705882352941174 | 0.502283105022831  | 0.5384615384615385 |      1.0      |            1.0             | 0.9893551778015014 |  0.6615705350938151   | 0.9078667611622963 | 0.0392156862745098  |        0.0         |       0.0       |          0.8125          | 0.6666666666666666  |        0.6         |       0.6000000000000001        |         0.875         |   0.0   | 0.7272727272727273 |   0.0   |
# | 3 | 0.39705882352941174 | 0.4931506849315068 | 0.6153846153846154 |      0.0      |            0.0             | 0.999504709159154  |  0.6316886726893676   | 0.5556343019135365 | 0.37254901960784315 |        0.0         |       0.0       |          0.8125          | 0.6666666666666666  | 0.7333333333333333 |               0.8               |         0.875         |   0.0   | 0.7272727272727273 |   0.0   |
# | 4 | 0.39705882352941174 | 0.502283105022831  | 0.6153846153846154 |      0.0      |            1.0             | 0.999984276481243  |  0.34746351633078526  | 0.593905031892275  | 0.9019607843137255  |        0.0         |       0.0       |          0.875           | 0.6666666666666666  |        0.6         |       0.6000000000000001        |         0.875         |   0.0   | 0.2727272727272727 |   0.0   |
# +---+---------------------+--------------------+--------------------+---------------+----------------------------+--------------------+-----------------------+--------------------+---------------------+--------------------+-----------------+--------------------------+---------------------+--------------------+---------------------------------+-----------------------+---------+--------------------+---------+
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[97], line 21
#      17 print(tabulate(US_data_scale.head(), headers='keys', tablefmt='pretty'))
#      19 # Step 3: Impute all missing values on the encoded & scaled data
#      20 # Note: Modify this to your imputer function if it only handles one column
# ---> 21 final_US_Imputing = impute_all_missing_values(
#      22     original_df=final_US_imputed,       # raw data (with NaNs)
#      23     encoded_df=US_data_scale            # processed data
#      24 )
#      26 print("Shape after full imputation:", final_US_Imputing.shape)
#
# NameError: name 'impute_all_missing_values' is not defined

# %% [markdown]
# ## **<span style="color:aquamarine;">Unsupervised Learning Outliers</span>**
# - There are no outlier detection methods for categorical data.
# - For Numerical columns only (Posted Speed Limit)
#
# - Can return back to before encoding as Numerical columns both use Last Occured hence easily imput and remove outliers
#
# - No outliers for datetime found in EDA but can check but... after imputing?

# %% [markdown]
# ### **Numerical Outliers**

# %% [markdown]
# ### **<span style="color:pink;">Z Score</span>**
# Measures how many standard deviations a data point is from the mean, identifying outliers as points with a high absolute Z-score

# %%
import numpy as np
import pandas as pd
from scipy import stats

def detect_outliers_zscore(df, threshold=3):
    numeric_series = pd.to_numeric(df["Posted Speed Limit (MPH)"], errors='coerce')
    z_scores = np.abs(stats.zscore(numeric_series, nan_policy='omit'))
    outliers = z_scores > threshold
    return outliers

uk_z_outliers = detect_outliers_zscore(UK_data)
print("UK outliers detected by Z-score:")
print(UK_data.loc[uk_z_outliers])

us_z_outliers = detect_outliers_zscore(US_data)
print("\nUS outliers detected by Z-score:")
print(US_data.loc[us_z_outliers])
# Out:
# UK outliers detected by Z-score:
# Empty DataFrame
# Columns: [Report ID, Report Version, Make, Model, Model Year, ADS Equipped?, Automation System Engaged?, Incident Date, Incident Time (24:00), City, State, Roadway Type, Roadway Surface, Posted Speed Limit (MPH), Lighting, Crash With, Highest Injury Severity Alleged, SV Pre-Crash Movement, Weather, SV Contact Area, Country]
# Index: []
#
# US outliers detected by Z-score:
# Empty DataFrame
# Columns: [Report ID, Report Version, Make, Model, Model Year, ADS Equipped?, Automation System Engaged?, Incident Date, Incident Time (24:00), City, State, Roadway Type, Roadway Surface, Posted Speed Limit (MPH), Lighting, Crash With, Highest Injury Severity Alleged, SV Pre-Crash Movement, Weather, SV Contact Area, Country]
# Index: []

# %% [markdown]
# ### **<span style="color:pink;">InterQuartile Range and Boxplot</span>**
# Uses the range between the 25th and 75th percentiles to detect outliers as points lying below Q1 − 1.5×IQR or above Q3 + 1.5×IQR.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def preprocess_numeric_column(df, col):
    df = df.copy()
    df[col] = pd.to_numeric(df[col], errors='coerce')
    df = df.dropna(subset=[col])
    return df

def detect_outliers_iqr(df, col):
    series = df[col]
    Q1 = series.quantile(0.25)
    Q3 = series.quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return (series < lower) | (series > upper)

def plot_boxplot(df, col, title, color, return_fig=False):
    plt.figure(figsize=(6, 5))
    sns.boxplot(y=df[col], color=color)
    plt.title(f"{col} - {title}")
    plt.ylabel(col)
    plt.tight_layout()
    if return_fig:
        return plt.gcf()
    else:
        plt.show()

# Usage examples:

# For Posted Speed Limit
UK_data = preprocess_numeric_column(UK_data, "Posted Speed Limit (MPH)")
US_data = preprocess_numeric_column(US_data, "Posted Speed Limit (MPH)")

uk_outliers_speed = detect_outliers_iqr(UK_data, "Posted Speed Limit (MPH)")
print("UK speed outliers:")
print(UK_data[uk_outliers_speed])

us_outliers_speed = detect_outliers_iqr(US_data, "Posted Speed Limit (MPH)")
print("\nUS speed outliers:")
print(US_data[us_outliers_speed])

plot_boxplot(UK_data, "Posted Speed Limit (MPH)", "UK", "skyblue")
plot_boxplot(US_data, "Posted Speed Limit (MPH)", "US", "skyblue")

# For Model Year
UK_data = preprocess_numeric_column(UK_data, "Model Year")
US_data = preprocess_numeric_column(US_data, "Model Year")

uk_outliers_year = detect_outliers_iqr(UK_data, "Model Year")
print("UK model year outliers:")
print(UK_data[uk_outliers_year])

us_outliers_year = detect_outliers_iqr(US_data, "Model Year")
print("\nUS model year outliers:")
print(US_data[us_outliers_year])

plot_boxplot(UK_data, "Model Year", "UK", "lightgreen")
plot_boxplot(US_data, "Model Year", "US", "lightgreen")
# Out:
# UK speed outliers:
#             Report ID Report Version        Make     Model  Model Year  \
# 160     2019010166508       10166508    MERCEDES   E CLASS      2014.0
# 214     2019010166923       10166923        FORD    FIESTA      2019.0
# 230     2019010167002       10167002         BMW        X3      2018.0
# 298     2019010167601       10167601  VOLKSWAGEN      GOLF      2002.0
# 413     2019010168638       10168638         BMW        X6      2012.0
# ...               ...            ...         ...       ...         ...
# 229774  2023991335534      991335534    VAUXHALL     MOKKA      2016.0
# 229776  2023991335544      991335544         BMW  3 SERIES      2017.0
# 229777  2023991335556      991335556         BMW        X1      2016.0
# 229779  2023991335835      991335835        FORD    MONDEO      2012.0
# 229780  2023991335837      991335837     PEUGEOT      3008      2018.0
#
#        ADS Equipped? Automation System Engaged? Incident Date  \
# 160     Conventional               Conventional    2019-03-01
# 214     Conventional               Conventional    2019-03-04
# 230     Conventional               Conventional    2019-03-05
# 298     Conventional               Conventional    2019-03-05
# 413     Conventional               Conventional    2019-03-12
# ...              ...                        ...           ...
# 229774  Conventional               Conventional    2023-07-30
# 229776  Conventional               Conventional    2023-07-28
# 229777  Conventional               Conventional    2023-07-27
# 229779  Conventional               Conventional    2023-07-31
# 229780  Conventional               Conventional    2023-07-31
#
#        Incident Time (24:00)          City     State        Roadway Type  \
# 160                 17:09:00      Osterley   England    Dual carriageway
# 214                 18:14:00  West Drayton   England    Dual carriageway
# 230                 07:40:00          Iver   England    Dual carriageway
# 298                 09:00:00  West Drayton   England           Slip road
# 413                 13:40:00   Potters Bar   England    Dual carriageway
# ...                      ...           ...       ...                 ...
# 229774              14:30:00       Portree  Scotland  Single carriageway
# 229776              16:00:00  Locharbriggs  Scotland  Single carriageway
# 229777              15:19:00       Peebles  Scotland  Single carriageway
# 229779              11:00:00     Mossblown  Scotland  Single carriageway
# 229780              10:05:00      Bothwell  Scotland    Dual carriageway
#
#        Roadway Surface  Posted Speed Limit (MPH)            Lighting  \
# 160                Dry                      60.0            Daylight
# 214                Dry                      70.0      Dark - Lighted
# 230                Dry                      70.0            Daylight
# 298                Dry                      70.0            Daylight
# 413                Wet                      70.0            Daylight
# ...                ...                       ...                 ...
# 229774             Dry                      60.0            Daylight
# 229776             Dry                      60.0            Daylight
# 229777             Wet                      60.0            Daylight
# 229779             Wet                      60.0  Dark - Not Lighted
# 229780             Wet                      60.0            Daylight
#
#        Crash With Highest Injury Severity Alleged    SV Pre-Crash Movement  \
# 160     No Object                           Minor  Waiting to go - held up
# 214     No Object                           Minor   Changing lane to right
# 230     No Object                           Minor    Changing lane to left
# 298     No Object                           Minor        Going ahead other
# 413     No Object                         Serious        Going ahead other
# ...           ...                             ...                      ...
# 229774  No Object                         Serious   Travelling around Bend
# 229776  No Object                         Serious        Going ahead other
# 229777  No Object                           Minor   Travelling around Bend
# 229779  No Object                         Serious   Travelling around Bend
# 229780  No Object                           Minor   Changing lane to right
#
#                       Weather SV Contact Area         Country
# 160                     Clear            Back  United Kingdom
# 214                     Clear         Offside  United Kingdom
# 230                     Clear        Nearside  United Kingdom
# 298                     Clear            Back  United Kingdom
# 413     Raining no high winds           Front  United Kingdom
# ...                       ...             ...             ...
# 229774                  Clear           Front  United Kingdom
# 229776                  Clear           Front  United Kingdom
# 229777                  Clear         Offside  United Kingdom
# 229779                  Clear           Front  United Kingdom
# 229780  Raining no high winds           Front  United Kingdom
#
# [46358 rows x 21 columns]
#
# US speed outliers:
# Empty DataFrame
# Columns: [Report ID, Report Version, Make, Model, Model Year, ADS Equipped?, Automation System Engaged?, Incident Date, Incident Time (24:00), City, State, Roadway Type, Roadway Surface, Posted Speed Limit (MPH), Lighting, Crash With, Highest Injury Severity Alleged, SV Pre-Crash Movement, Weather, SV Contact Area, Country]
# Index: []
# UK model year outliers:
#             Report ID Report Version        Make     Model  Model Year  \
# 650     2019010170671       10170671    MERCEDES   C CLASS      1995.0
# 1240    2019010175235       10175235         BMW  3 SERIES      1990.0
# 1660    2019010178801       10178801  VOLKSWAGEN      GOLF      1982.0
# 1784    2019010179571       10179571        FORD    FIESTA      1991.0
# 1953    2019010180921       10180921    VAUXHALL     CORSA      1995.0
# ...               ...            ...         ...       ...         ...
# 226406  202360A038009      60A038009  MITSUBISHI    SHOGUN      1995.0
# 226599  202360A119732      60A119732        FORD    MONDEO      1994.0
# 227249  2023622300374      622300374        FORD    ESCORT      1990.0
# 229204  2023991307546      991307546       HONDA     CIVIC      1995.0
# 229347  2023991315231      991315231  VOLKSWAGEN      GOLF      1992.0
#
#        ADS Equipped? Automation System Engaged? Incident Date  \
# 650     Conventional               Conventional    2019-03-22
# 1240    Conventional               Conventional    2019-04-15
# 1660    Conventional               Conventional    2019-05-03
# 1784    Conventional               Conventional    2019-05-08
# 1953    Conventional               Conventional    2019-05-14
# ...              ...                        ...           ...
# 226406  Conventional               Conventional    2023-03-16
# 226599  Conventional               Conventional    2023-07-29
# 227249  Conventional               Conventional    2023-05-06
# 229204  Conventional               Conventional    2023-05-14
# 229347  Conventional               Conventional    2023-06-04
#
#        Incident Time (24:00)            City     State        Roadway Type  \
# 650                 19:40:00     Walthamstow   England  Single carriageway
# 1240                10:10:00  Crystal Palace   England  Single carriageway
# 1660                22:25:00           Erith   England    Dual carriageway
# 1784                11:50:00     Chislehurst   England  Single carriageway
# 1953                16:39:00       Becontree   England    Dual carriageway
# ...                      ...             ...       ...                 ...
# 226406              08:30:00   Llanerchymedd     Wales  Single carriageway
# 226599              15:47:00       Marchwiel     Wales  Single carriageway
# 227249              14:35:00         Aberfan     Wales    Dual carriageway
# 229204              13:45:00         Kintore  Scotland  Single carriageway
# 229347              22:20:00        Sanquhar  Scotland  Single carriageway
#
#        Roadway Surface  Posted Speed Limit (MPH)            Lighting  \
# 650                Dry                      20.0      Dark - Lighted
# 1240               Dry                      30.0            Daylight
# 1660               Wet                      40.0      Dark - Lighted
# 1784               Wet                      30.0            Daylight
# 1953               Dry                      30.0            Daylight
# ...                ...                       ...                 ...
# 226406             Wet                      30.0            Daylight
# 226599             Dry                      50.0            Daylight
# 227249             Wet                      70.0            Daylight
# 229204             Wet                      60.0            Daylight
# 229347             Dry                      60.0  Dark - Not Lighted
#
#            Crash With Highest Injury Severity Alleged   SV Pre-Crash Movement  \
# 650         No Object                           Minor       Making Right Turn
# 1240        No Object                           Minor   Changing lane to left
# 1660    Bridge (side)                         Serious       Going ahead other
# 1784        No Object                           Minor       Making Right Turn
# 1953        No Object                           Minor       Going ahead other
# ...               ...                             ...                     ...
# 226406      No Object                           Minor              Moving off
# 226599      No Object                         Serious              Moving off
# 227249      No Object                           Minor       Going ahead other
# 229204      No Object                           Minor  Travelling around Bend
# 229347      No Object                         Serious       Going ahead other
#
#                       Weather SV Contact Area         Country
# 650                     Clear  Did not impact  United Kingdom
# 1240                    Clear           Front  United Kingdom
# 1660                    Clear           Front  United Kingdom
# 1784     Raining + high winds        Nearside  United Kingdom
# 1953                    Clear        Nearside  United Kingdom
# ...                       ...             ...             ...
# 226406                  Clear           Front  United Kingdom
# 226599                  Clear           Front  United Kingdom
# 227249  Raining no high winds           Front  United Kingdom
# 229204  Raining no high winds         Offside  United Kingdom
# 229347                  Clear        Nearside  United Kingdom
#
# [455 rows x 21 columns]
#
# US model year outliers:
#         Report ID  Report Version     Make       Model  Model Year  \
# 132   13781-10020               1    Tesla     Model X      2017.0
# 134   13781-10022               1    Tesla     Model X      2017.0
# 158   13781-10093               1    Tesla     Model X      2016.0
# 197   13781-10197               1    Tesla     Model X      2017.0
# 207   13781-10248               1    Tesla     Model X      2016.0
# ...           ...             ...      ...         ...         ...
# 3874   30610-9726               1   Toyota  Highlander      2017.0
# 3875   30610-9759               1   Toyota  Highlander      2017.0
# 3894   30792-1031               1  Lincoln         MKZ      2017.0
# 3922   33495-6725               1  Lincoln  MKZ Hybrid      2017.0
# 3923   33495-6726               1  Lincoln  MKZ Hybrid      2016.0
#
#      ADS Equipped?   Automation System Engaged? Incident Date  \
# 132             No                         ADAS    2025-10-23
# 134             No                         ADAS    2025-10-23
# 158             No                         ADAS    2025-11-23
# 197             No                         ADAS    2025-03-25
# 207             No                         ADAS    2025-03-25
# ...            ...                          ...           ...
# 3874           Yes                          ADS    2025-01-10
# 3875           Yes                          ADS    2025-01-10
# 3894           Yes                          ADS    2021-07-10
# 3922           Yes  Not Provided, see Narrative    2023-09-10
# 3923           Yes  Not Provided, see Narrative    2023-10-10
#
#      Incident Time (24:00)           City State       Roadway Type  \
# 132               02:28:00  San Francisco   CA        Not Provided
# 134               00:43:00  Thousand Oaks   CA          Rural Road
# 158               02:06:00   Mount Vernon   WA        Not Provided
# 197               16:17:00        Phoenix   AZ   Highway / Freeway
# 207               21:29:00     Scottsdale   AZ        Not Provided
# ...                    ...            ...   ...                ...
# 3874              10:16:00       Paradise   NV              Street
# 3875              22:57:00  San Francisco   CA              Street
# 3894              11:35:00       San Jose   CA              Street
# 3922              12:25:00  San Francisco   CA              Street
# 3923              12:01:00  San Francisco   CA        Intersection
#
#      Roadway Surface  Posted Speed Limit (MPH)        Lighting  \
# 132     Not Provided                      45.0    Not Provided
# 134              Dry                      45.0        Daylight
# 158     Not Provided                      60.0    Not Provided
# 197              Dry                      65.0        Daylight
# 207     Not Provided                      65.0    Not Provided
# ...              ...                       ...             ...
# 3874             Dry                      45.0        Daylight
# 3875             Dry                      25.0  Dark - Lighted
# 3894             Dry                      35.0        Daylight
# 3922             Dry                      25.0        Daylight
# 3923             Dry                      25.0        Daylight
#
#                 Crash With Highest Injury Severity Alleged  \
# 132           Not Provided                    Not Provided
# 134          Passenger Car                    Not Provided
# 158           Not Provided                    Not Provided
# 197                    SUV                    Not Provided
# 207           Not Provided                    Not Provided
# ...                    ...                             ...
# 3874                   SUV            No Injuries Reported
# 3875         Passenger Car            No Injuries Reported
# 3894                   SUV            No Injuries Reported
# 3922                   SUV            No Injuries Reported
# 3923  Other, see Narrative            No Injuries Reported
#
#       SV Pre-Crash Movement  Weather        SV Contact Area Country
# 132            Not Provided  Missing                Missing      US
# 134   Lane / Road Departure    Clear  Back, Front, Nearside      US
# 158            Not Provided  Missing                Missing      US
# 197     Proceeding Straight    Clear                  Front      US
# 207            Not Provided  Missing                Missing      US
# ...                     ...      ...                    ...     ...
# 3874    Proceeding Straight    Clear               Nearside      US
# 3875    Proceeding Straight    Clear               Nearside      US
# 3894    Proceeding Straight    Clear                   Back      US
# 3922         Changing Lanes    Clear                  Front      US
# 3923    Proceeding Straight    Clear                  Front      US
#
# [162 rows x 21 columns]

# %%
# Drop rows where Model Year < 1980
UK_data = UK_data[UK_data["Model Year"] >= 1990].reset_index(drop=True)
US_data = US_data[US_data["Model Year"] >= 1990].reset_index(drop=True)

# %% [markdown]
# ### **<span style="color:pink;">Boxplot</span>**
# same as IQR just visual
# Uses the range between the 25th and 75th percentiles to detect outliers as points lying below Q1 − 1.5×IQR or above Q3 + 1.5×IQR.

# %% [markdown]
# - no outliers found in either sets
# - UK boxplot shows 60 and 70 to be outlier but these are totally normal motorway speeds and not caught by Z or IQR

# %% [markdown]
# ## **<span style="color:aquamarine;">Sampling Dataset</span>**

# %% [markdown]
# ### **<span style="color:Hotpink;">Systematic</span>**

# %%
import pandas as pd
import numpy as np

def systematic_sampling(df, sample_size=4000):
    population_size = len(df)
    step = population_size // sample_size
    start = np.random.randint(0, step)
    indices = np.arange(start, start + step * sample_size, step)
    indices = indices[indices < population_size]
    return df.iloc[indices]

# %% [markdown]
# ### **<span style="color:Hotpink;">Stratified</span>**

# %%
def stratified_sampling(df, stratify_col, frac=0.2, random_state=42):
    return df.groupby(stratify_col, group_keys=False).apply(
        lambda x: x.sample(frac=frac, random_state=random_state)
    )

# %% [markdown]
# ### **<span style="color:Hotpink;">Random</span>**

# %%
def random_sampling(df, frac=0.2, random_state=42):
    return df.sample(frac=frac, random_state=random_state)

# %% [markdown]
# ### **<span style="color:Hotpink;">Cluster</span>**

# %%
def cluster_sampling(df, cluster_col):
    clusters = df[cluster_col].unique()
    chosen_cluster = np.random.choice(clusters)
    sample = df[df[cluster_col] == chosen_cluster]
    return sample, chosen_cluster

# %% [markdown]
# ### **<span style="color:Hotpink;">KNN</span>**

# %%
def knn_sampling(df, frac=0.2):
    X = df.values
    random_point = X[np.random.choice(len(X))]
    nbrs = NearestNeighbors(n_neighbors=int(len(X)*frac)).fit(X)
    distances, indices = nbrs.kneighbors([random_point])
    return df.iloc[indices[0]]

# %% [markdown]
# ### **<span style="color:GreenYellow;">Evaluating: Sampling Methods</span>**

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt


# Evaluation plot function (same as yours)
def evaluate_sample(sample, full_data, name):
    means_full = full_data.mean()
    means_sample = sample.mean()
    bias = means_sample - means_full
    
    features = full_data.columns
    x = np.arange(len(features))
    width = 0.35
    
    fig, ax1 = plt.subplots(figsize=(12,6))
    rects1 = ax1.bar(x - width/2, means_full, width, label='Full Data Mean', color='skyblue')
    rects2 = ax1.bar(x + width/2, means_sample, width, label='Sample Mean', color='orange')
    ax1.set_ylabel('Mean Values')
    ax1.set_xticks(x)
    ax1.set_xticklabels(features, rotation=45, ha='right')
    ax1.legend(loc='upper left')
    
    ax2 = ax1.twinx()
    ax2.plot(x, bias, color='red', marker='o', linestyle='-', label='Bias (Sample - Full)')
    ax2.set_ylabel('Bias')
    ax2.legend(loc='upper right')
    
    plt.title(f'{name} Feature-wise Mean Comparison and Bias')
    plt.tight_layout()
    plt.show()

# %%
# Main function to run all samplings and evaluations
def run_all_sampling_methods(data, stratify_col):

    # 1. Random Sampling
    random_sample = random_sampling(data)
    print("Random Sampling:")
    evaluate_sample(random_sample, data, "Random ")

    # 2. Systematic Sampling
    systematic_sample = systematic_sampling(data)
    print("Systematic Sampling:")
    evaluate_sample(systematic_sample, data, "Systematic ")

    # 3. Stratified Sampling
    stratified_sample = stratified_sampling(data, stratify_col)
    print("Stratified Sampling:")
    evaluate_sample(stratified_sample, data, "Stratified ")

    # 4. Cluster Sampling
    cluster_sample, chosen_cluster = cluster_sampling(data, stratify_col)
    print(f"Cluster Sampling (cluster '{chosen_cluster}'):")
    evaluate_sample(cluster_sample, data, "Cluster ")

    # 5. KNN Sampling
    knn_sample = knn_sampling(data)
    print("KNN Sampling:")
    evaluate_sample(knn_sample, data, "KNN ")

    # Return samples if needed
    return {
        "random_sample": random_sample,
        "systematic_sample": systematic_sample,
        "stratified_sample": stratified_sample,
        "cluster_sample": cluster_sample,
        "knn_sample": knn_sample
    }

# %% [markdown]
# **UK Dataset**

# %%
# Assuming your original data is in variable `data`
final_UK_Imputing = UK_data.drop(columns=['ADS Equipped?', 'Automation System Engaged?'], errors='ignore')
# samples = run_all_sampling_methods(final_UK_Imputing, stratify_col='Highest Injury Severity Alleged')

# %% [markdown]
# **US Dataset**

# %%
# Assuming your original data is in variable `data`
# samples = run_all_sampling_methods(US_data, stratify_col='Highest Injury Severity Alleged')

# %% [markdown]
# ### **Final Samples**

# %% [markdown]
# - sampling not required as this will be misleading

# %% [markdown]
# ## **<span style="color:aquamarine;">Feature Selection</span>**

# %%
def encode_df(df, categorical_columns, datetime_columns):
    df_encoded = df.copy()

    # Convert datetime columns to numeric timestamps
    if 'Incident Date' in datetime_columns and 'Incident Date' in df_encoded.columns:
        df_encoded['Incident Date'] = pd.to_datetime(df_encoded['Incident Date'], errors='coerce')
        df_encoded['Incident Date'] = df_encoded['Incident Date'].astype('int64') // 10**9  # Unix timestamp

    if 'Incident Time (24:00)' in datetime_columns and 'Incident Time (24:00)' in df_encoded.columns:
        time_parsed = pd.to_datetime(df_encoded['Incident Time (24:00)'], format='%H:%M:%S', errors='coerce')
        df_encoded['Incident Time (24:00)'] = (
            time_parsed.dt.hour * 3600 +
            time_parsed.dt.minute * 60 +
            time_parsed.dt.second
        )

    # Encode categorical columns
    label_encoders = {}
    for col in categorical_columns:
        if col in df_encoded.columns:
            le = LabelEncoder()
            df_encoded[col] = le.fit_transform(df_encoded[col].astype(str))
            label_encoders[col] = le

    return df_encoded, label_encoders

# %%
def scale_df(df, columns):
    scaler = MinMaxScaler()
    scaled_values = scaler.fit_transform(df[columns])
    df_scaled = pd.DataFrame(scaled_values, columns=columns, index=df.index)
    return df_scaled, scaler

# %%
def plot_correlation_heatmap(df, title="Correlation Heatmap", figsize=(18, 14)):
    plt.figure(figsize=figsize)
    sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")
    plt.title(title, fontsize=16)
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## **UK Dataset**

# %%
# === Usage Example ===

# Define columns (same as your original lists)
numerical_columns = ['Posted Speed Limit (MPH)']
categorical_columns = [
    'Make', 'Model', 'Model Year', 'City', 'State', 'Roadway Type', 'Roadway Surface',
    'Lighting', 'Crash With', 'Highest Injury Severity Alleged',
    'SV Pre-Crash Movement', 'SV Contact Area', 'Weather',
]
datetime_columns = ['Incident Date', 'Incident Time (24:00)']

# Step 1: Encode dataframe
df_encoded, encoders = encode_df(UK_data, categorical_columns, datetime_columns)

# Step 2: Select columns to scale
heatmap_columns = numerical_columns + categorical_columns + datetime_columns

# Step 3: Scale dataframe
UK_df_scaled, scaler = scale_df(df_encoded, heatmap_columns)

# Step 5: Imputing 
UK_df_scaled = UK_df_scaled.dropna()

# Step 4: Plot full heatmap
plot_correlation_heatmap(UK_df_scaled, title="Correlation Heatmap (Scaled, Encoded, Timestamped Features)")

# Step 5: Plot top 10 features correlated with 'Highest Injury Severity Alleged'
target_col = 'Highest Injury Severity Alleged'
corr_matrix = UK_df_scaled.corr()
target_corr = corr_matrix[target_col].abs().sort_values(ascending=False)
top_features = target_corr.index.drop(target_col).to_list()
top_10_features = top_features[:10] + [target_col]

plot_correlation_heatmap(UK_df_scaled[top_10_features], 
                         title="Top 10 Features Correlated with Highest Injury Severity Alleged", 
                         figsize=(10, 8))

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

# === Define column groups ===
numerical_columns = ['Posted Speed Limit (MPH)']
categorical_columns = [
    'Make', 'Model', 'Model Year', 'ADS Equipped?',
    'Automation System Engaged?', 'City', 'State', 'Roadway Type', 'Roadway Surface',
    'Lighting', 'Crash With', 'Highest Injury Severity Alleged',
    'SV Pre-Crash Movement', 'SV Contact Area', 'Weather', 
]
datetime_columns = ['Incident Date', 'Incident Time (24:00)']
indexing_columns = ['Report ID', 'Report Version']

# === Copy and preprocess dataframe ===
df = US_data
df.dropna()
df_encoded = df.copy()

# --- Convert datetime columns to numeric ---
df_encoded['Incident Date'] = pd.to_datetime(df_encoded['Incident Date'], errors='coerce')
df_encoded['Incident Date'] = df_encoded['Incident Date'].astype('int64') // 10**9  # Unix timestamp

# Correct time parsing for format with seconds
if 'Incident Time (24:00)' in df_encoded.columns:
    time_parsed = pd.to_datetime(df_encoded['Incident Time (24:00)'], format='%H:%M:%S', errors='coerce')
    df_encoded['Incident Time (24:00)'] = (
        time_parsed.dt.hour * 3600 +
        time_parsed.dt.minute * 60 +
        time_parsed.dt.second
    )

# --- Encode categorical columns ---
label_encoders = {}
for col in categorical_columns:
    le = LabelEncoder()
    df_encoded[col] = le.fit_transform(df_encoded[col].astype(str))
    label_encoders[col] = le

# === Select relevant columns ===
heatmap_columns = numerical_columns + categorical_columns + datetime_columns
df_heatmap = df_encoded[heatmap_columns]

# --- MinMax Scaling ---
scaler = MinMaxScaler()
df_heatmap_scaled = pd.DataFrame(scaler.fit_transform(df_heatmap), columns=heatmap_columns)

# === Plot the heatmap ===
plt.figure(figsize=(18, 14))
sns.heatmap(df_heatmap_scaled.corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap (Scaled, Encoded, and Timestamped Features)", fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# Step 5: Plot top 10 features correlated with 'Highest Injury Severity Alleged'
target_col = 'Highest Injury Severity Alleged'
corr_matrix = df_heatmap.corr()
target_corr = corr_matrix[target_col].abs().sort_values(ascending=False)
top_features = target_corr.index.drop(target_col).to_list()
top_10_features = top_features[:10] + [target_col]

plot_correlation_heatmap(df_heatmap[top_10_features], 
                         title="Top 10 Features Correlated with Highest Injury Severity Alleged", 
                         figsize=(10, 8))

# %% [markdown]
# **Save the Imputed Original and Scaled DFs**

# %%
# For clustering
# US_df_scaled.to_csv('US_df_scaled.csv', index=False)
# UK_df_scaled.to_csv('UK_df_scaled.csv', index=False)

# US
# Final_US_Imputing = US_data.dropna()
# Final_US_Imputing.to_csv('Imputed_Raw_US_df.csv', index=False)

# UK need to add the regression uk and then decode back
