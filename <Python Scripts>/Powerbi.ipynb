# %%
import pandas as pd

# File paths
US_df_path = '/Users/mahnooriqbal/COMP702 Project/ML-AI-Risk-Analysis-AV-Data-/Datasets/US_imputed_data.csv'
UK_df_path = "/Users/mahnooriqbal/COMP702 Project/ML-AI-Risk-Analysis-AV-Data-/Datasets/UK/UK-cleaned_data.csv"

# Load CSV files into DataFrames
US_df = pd.read_csv(US_df_path)
UK_df = pd.read_csv(UK_df_path)
# Out:
# /var/folders/0k/whv99z5n5rnb1xp8n07krpcw0000gn/T/ipykernel_4828/2970215838.py:9: DtypeWarning: Columns (0,1) have mixed types. Specify dtype option on import or set low_memory=False.
#   UK_df = pd.read_csv(UK_df_path)

# %%
print("US DataFrame:")
US_df.head()
# Out:
# US DataFrame:
#      Report ID  Report Version Make         Model  Model Year ADS Equipped?  \
# 0  10039-10316               4  BMW            XM      2023.0            No
# 1   10039-3997               3  BMW  X5 sDrive40i      2020.0            No
# 2   10039-4636               4  BMW            X5      2022.0            No
# 3   10039-6833               4  BMW   iX xDrive50      2023.0            No
# 4      10039-8               3  BMW  X5 xDrive40i      2019.0            No
#
#   Automation System Engaged? Incident Date Incident Time (24:00)  \
# 0                       ADAS    2025-03-25              14:06:00
# 1                       ADAS    2025-05-22              22:25:00
# 2                       ADAS    2025-12-22              07:05:00
# 3                       ADAS    2025-12-23              06:00:00
# 4                       ADAS    2025-07-21              03:01:00
#
#             City  ...       Roadway Type Roadway Surface  \
# ...

# %%
print("UK DataFrame:")
UK_df = UK_df.drop(columns=['latitude', 'longitude'])
UK_df.head()
# Out:
# UK DataFrame:
#        Report ID Report Version      Make    Model  Model Year ADS Equipped?  \
# 0  2019010155206       10155206    SUZUKI    SWIFT        2015  Conventional
# 1  2019010155217       10155217   HYUNDAI      I30        2015  Conventional
# 2  2019010155425       10155425  MERCEDES  C CLASS        2018  Conventional
# 3  2019010156538       10156538    TOYOTA  AVENSIS        2005  Conventional
# 4  2019010156721       10156721      AUDI       A4        2017  Conventional
#
#   Automation System Engaged? Incident Date Incident Time (24:00)  \
# 0               Conventional    2019-01-01              01:15:00
# 1               Conventional    2019-01-01              04:10:00
# 2               Conventional    2019-01-02              15:07:00
# 3               Conventional    2019-01-08              21:20:00
# 4               Conventional    2019-01-10              08:20:00
#
#              City  ...        Roadway Type Roadway Surface  \
# ...

# %%
common_cols = US_df.columns.intersection(UK_df.columns)

# Select only the common columns in both DataFrames to avoid mismatches
US_common = US_df[common_cols]
UK_common = UK_df[common_cols]

# Concatenate rows
merged_df = pd.concat([US_common, UK_common], axis=0, ignore_index=True)

merged_df.head()
# Out:
#      Report ID Report Version Make         Model  Model Year ADS Equipped?  \
# 0  10039-10316              4  BMW            XM      2023.0            No
# 1   10039-3997              3  BMW  X5 sDrive40i      2020.0            No
# 2   10039-4636              4  BMW            X5      2022.0            No
# 3   10039-6833              4  BMW   iX xDrive50      2023.0            No
# 4      10039-8              3  BMW  X5 xDrive40i      2019.0            No
#
#   Automation System Engaged? Incident Date Incident Time (24:00)  \
# 0                       ADAS    2025-03-25              14:06:00
# 1                       ADAS    2025-05-22              22:25:00
# 2                       ADAS    2025-12-22              07:05:00
# 3                       ADAS    2025-12-23              06:00:00
# 4                       ADAS    2025-07-21              03:01:00
#
#             City  ...       Roadway Type Roadway Surface  \
# 0  Benton County  ...  Highway / Freeway             Dry
# ...

# %%
merged_df.shape
# Out:
# (233814, 21)

# %%
output_file = '/Users/mahnooriqbal/COMP702 Project/ML-AI-Risk-Analysis-AV-Data-/Datasets/combined_risk_analysis_PBi.csv'
merged_df.to_csv(output_file, index=False)
print(f"Merged data saved to {output_file}")
# Out:
# Merged data saved to /Users/mahnooriqbal/COMP702 Project/ML-AI-Risk-Analysis-AV-Data-/Datasets/combined_risk_analysis_PBi.csv
